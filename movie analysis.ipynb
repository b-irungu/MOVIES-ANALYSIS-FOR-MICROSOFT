# %% [markdown]
# **DETERMINING THE FACTORS MICROSOFT,A NEW ENTRANT IN THE MOVIE PRODUCTION INDUSTRY, SHOULD CONSIDER TO ATTAIN SUCCESS USING EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# **PROJECT OVERVIEW**

# %% [markdown]
# This project uses data named zippedData which includes movie datasets derived from Box Office Mojo, IMBD, Rotten Tomatoes, The MovieDB, and The Numbers. The project will utilize various data files to conduct an exploratory analysis with an aim of deriving recommendations to the Microsoft new movies studio on what movies to produce.

# %% [markdown]
# **PROBLEM STATEMENT**

# %% [markdown]
# Microsoft sees all the big companies creating original video content and they want to get in on the fun. They have decided to create a new movie studio, but they don’t know anything about creating movies. You are charged with exploring what types of films are currently doing the best at the box office. You must then translate those findings into actionable insights that the head of Microsoft's new movie studio can use to help decide what type of films to create.

# %% [markdown]
# The objectives of this Exploratory Data Analysis include the following;
# * To determine the most profitable studios which canbe used for benchmarking
# * To determine what genre is most profitable
# * To determine the cost of producing the most profitable movies

# %% [markdown]
# **DATA PRE-PROCESSING**

# %% [markdown]
# In this analysis we will use data drom zippedData file but especially the following data files:
#
# * imdb.title.basics
# * imdb.title.ratings
# * bom.movie_gross
# * tn.movie_budgets

# %% [markdown]
# lets start by importing pandas and numpy

# %%
# import pandas and numpy
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# uploading and reading files
movie_gross = pd.read_csv('bom.movie_gross.csv', index_col = 0) #reads the bom.movie_gross. csv file
title_basics = pd.read_csv('title.basics.csv', index_col = 0) #reads the title.basics.csv file
title_ratings = pd.read_csv('title.ratings.csv', index_col = 0) 
movie_budgets = pd.read_csv('tn.movie_budgets.csv.gz', index_col = 0)

# %%
movie_gross.head() #opens the first 5 observations
# Out:
#                                             studio  domestic_gross  \
# title
# Toy Story 3                                     BV     415000000.0
# Alice in Wonderland (2010)                      BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# Inception                                       WB     292600000.0
# Shrek Forever After                           P/DW     238700000.0
#
#                                             foreign_gross  year
# title
# Toy Story 3                                     652000000  2010
# Alice in Wonderland (2010)                      691300000  2010
# Harry Potter and the Deathly Hallows Part 1     664300000  2010
# Inception                                       535700000  2010
# Shrek Forever After                             513900000  2010

# %%
title_basics.head()
# Out:
#                              primary_title              original_title  \
# tconst
# tt0063540                        Sunghursh                   Sunghursh
# tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# tt0069049       The Other Side of the Wind  The Other Side of the Wind
# tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#            start_year  runtime_minutes                genres
# tconst
# tt0063540        2013            175.0    Action,Crime,Drama
# tt0066787        2019            114.0       Biography,Drama
# tt0069049        2018            122.0                 Drama
# tt0069204        2018              NaN          Comedy,Drama
# tt0100275        2017             80.0  Comedy,Drama,Fantasy

# %%
title_ratings.head()
# Out:
#             averagerating  numvotes
# tconst
# tt10356526            8.3        31
# tt10384606            8.9       559
# tt1042974             6.4        20
# tt1043726             4.2     50352
# tt1060240             6.5        21

# %%
movie_budgets.head()
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# 4       $330,600,000   $459,005,868  $1,403,013,963
# 5       $317,000,000   $620,181,382  $1,316,721,747

# %% [markdown]
# **DATA SET 'movie_gross' PREPROCESSING**

# %%
movie_gross.tail()#prints the last five observations
# Out:
#                                  studio  domestic_gross foreign_gross  year
# title
# The Quake                         Magn.          6200.0           NaN  2018
# Edward II (2018 re-release)          FM          4800.0           NaN  2018
# El Pacto                           Sony          2500.0           NaN  2018
# The Swan                     Synergetic          2400.0           NaN  2018
# An Actor Prepares                 Grav.          1700.0           NaN  2018

# %% [markdown]
# lets check the summary of the 'movie_gross'data set to have an idea of what we are dealing with.

# %%
movie_gross.info()#printing the summary of the dataframe using the .info() function
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3387 entries, Toy Story 3 to An Actor Prepares
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   studio          3382 non-null   object
#  1   domestic_gross  3359 non-null   float64
#  2   foreign_gross   2037 non-null   object
#  3   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 132.3+ KB

# %%
movie_gross.shape #checks the number of rows and columns in the dataset.
# Out:
# (3387, 4)

# %%
type('movie_gross')# checks the type of the data
# Out:
# str

# %% [markdown]
# **Checking for duplicates**

# %%
movie_gross.duplicated().value_counts() #checks and generates the number of duplicated values in the data set
# Out:
# False    3376
# True       11
# dtype: int64

# %% [markdown]
# The output above indicates that they are 11 duplicates in the data. lets check the duplicates in the cell below.

# %%
movie_gross.duplicated(keep=False)
# Out:
# title
# Toy Story 3                                    False
# Alice in Wonderland (2010)                     False
# Harry Potter and the Deathly Hallows Part 1    False
# Inception                                      False
# Shrek Forever After                            False
#                                                ...
# The Quake                                      False
# Edward II (2018 re-release)                    False
# El Pacto                                       False
# The Swan                                       False
# An Actor Prepares                              False
# Length: 3387, dtype: bool

# %% [markdown]
# **Checking missing data**

# %%
movie_gross.isna() # checks the missing values
# Out:
#                                              studio  domestic_gross  \
# title
# Toy Story 3                                   False           False
# Alice in Wonderland (2010)                    False           False
# Harry Potter and the Deathly Hallows Part 1   False           False
# Inception                                     False           False
# Shrek Forever After                           False           False
# ...                                             ...             ...
# The Quake                                     False           False
# Edward II (2018 re-release)                   False           False
# El Pacto                                      False           False
# The Swan                                      False           False
# An Actor Prepares                             False           False
#
#                                              foreign_gross   year
# title
# Toy Story 3                                          False  False
# Alice in Wonderland (2010)                           False  False
# Harry Potter and the Deathly Hallows Part 1          False  False
# Inception                                            False  False
# Shrek Forever After                                  False  False
# ...                                                    ...    ...
# The Quake                                             True  False
# Edward II (2018 re-release)                           True  False
# El Pacto                                              True  False
# The Swan                                              True  False
# An Actor Prepares                                     True  False
#
# [3387 rows x 4 columns]

# %%
movie_gross.isna().sum() # checks the sum of missing data in the dataframe
# Out:
# studio               5
# domestic_gross      28
# foreign_gross     1350
# year                 0
# dtype: int64

# %% [markdown]
# Now that we know that there are missing values in the columns 'studio', 'domestic_gross',and 'foreign_gross', we will examine the columns closely.we will check the percentage of missing rows in the colums and also check the the number of unique values in the columns.

# %%
len(movie_gross[movie_gross.studio.isna()])/ len(movie_gross) # checks % of missing rows in 'studio'
# Out:
# 0.0014762326542663124

# %%
len(movie_gross[movie_gross.domestic_gross.isna()])/ len(movie_gross) # checks % of missing rows in 'domestic_gross'
# Out:
# 0.008266902863891349

# %%
len(movie_gross[movie_gross.foreign_gross.isna()])/ len(movie_gross) #checks% of missing rows in 'foreign_gross'
# Out:
# 0.3985828166519043

# %%
movie_gross.studio.nunique() #checks unique values in column 'studio'
# Out:
# 257

# %%
movie_gross.domestic_gross.nunique() # checks unique values in column 'domestic_gross'
# Out:
# 1797

# %%
movie_gross.foreign_gross.nunique() # checks unique values in 'foreign_gross'
# Out:
# 1204

# %% [markdown]
# since we have identified the missing data percentage and the unique values in the colums, we will then continue to deal with the missing data in each column separately

# %% [markdown]
# **Replacing** the mising values in column 'studio' using forward fill

# %%
movie_gross['studio'].fillna(method='ffill', inplace=True) #forward filling missing values using .finna()

# %%
movie_gross['studio'].isna().sum() #confirms replacement was successfull.
# Out:
# 0

# %% [markdown]
# **Replacing** the missing values in column 'domestic_gross' using the **median** in the cells below

# %%
movie_gross['domestic_gross'].median() #generates the median

print("Median is", movie_gross['domestic_gross'].median()) #prints out the median
# Out:
# Median is 1400000.0

# %%
movie_gross['domestic_gross'] = movie_gross['domestic_gross'].fillna(value=movie_gross['domestic_gross'].median) 
# fills in the the missing value using the median value

# %%
movie_gross['domestic_gross'].isna().sum() #confirms that missing
# Out:
# 0

# %% [markdown]
# **Replacing** the missing values in foreign_gross with 0

# %%
movie_gross['foreign_gross'].fillna(value= 0, inplace=True) #replaces missing values with 0

# %%
movie_gross['foreign_gross'].isna().sum() confirms replacement
# Out:
# 0

# %%
movie_gross.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3387 entries, Toy Story 3 to An Actor Prepares
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   studio          3387 non-null   object
#  1   domestic_gross  3359 non-null   float64
#  2   foreign_gross   3387 non-null   object
#  3   year            3387 non-null   int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 132.3+ KB

# %% [markdown]
# **DATA SET 'title_basics'PREPROCESSING**

# %%
title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146144 entries, tt0063540 to tt9916754
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   primary_title    146144 non-null  object
#  1   original_title   146123 non-null  object
#  2   start_year       146144 non-null  int64
#  3   runtime_minutes  114405 non-null  float64
#  4   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 6.7+ MB

# %%
title_basics.isna() #checks whether they are missing values
# Out:
#            primary_title  original_title  start_year  runtime_minutes  genres
# tconst
# tt0063540          False           False       False            False   False
# tt0066787          False           False       False            False   False
# tt0069049          False           False       False            False   False
# tt0069204          False           False       False             True   False
# tt0100275          False           False       False            False   False
# ...                  ...             ...         ...              ...     ...
# tt9916538          False           False       False            False   False
# tt9916622          False           False       False             True   False
# tt9916706          False           False       False             True   False
# tt9916730          False           False       False            False    True
# tt9916754          False           False       False             True   False
#
# [146144 rows x 5 columns]

# %%
title_basics.isna().sum() #checks the total number of missing values
# Out:
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %% [markdown]
# From the cell above, it is clear that we have 21 missing values in the 'original_title' column, 31739 in the 'runtime_minutes' column and 5408 in the 'genres' column.lets check the percentage of unique values in the dataset using the specific columns so as to determine the best method to handle the missing values.

# %%
len(title_basics[title_basics.original_titple.isna()])/ len(title_basics) # checks % of missing rows in 'original_title'
# Out:
# 0.00014369389095686446

# %%
len(title_basics[title_basics.runtime_minutes.isna()])/ len(title_basics) # checks % of missing rows in 'runtime_minutes'
# Out:
# 0.21717620976571053

# %%
len(title_basics[title_basics.genres.isna()])/ len(title_basics) # checks % of missing rows in 'genres'
# Out:
# 0.037004598204510616

# %% [markdown]
# To deal with missing data in the data set, we will;
# * **Replace** missing values of the 'original title' with the value of its 'primary_title'
# * **Fill** in the missing values in 'runtime_minutes' with forwad fill
# * **Replace** missing values in 'genres' eith the value 'Missing'

# %%
title_basics['original_title'].fillna(value= 'primary_title', inplace=True)

# %%
title_basics['runtime_minutes'].fillna(method='ffill', inplace=True)

# %%
title_basics['genres'].fillna(value= 'Missing', inplace=True)

# %%
title_basics.isna().sum() #confirms replacement was successfull
# Out:
# primary_title      0
# original_title     0
# start_year         0
# runtime_minutes    0
# genres             0
# dtype: int64

# %%
title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 146144 entries, tt0063540 to tt9916754
# Data columns (total 5 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   primary_title    146144 non-null  object
#  1   original_title   146144 non-null  object
#  2   start_year       146144 non-null  int64
#  3   runtime_minutes  146144 non-null  float64
#  4   genres           146144 non-null  object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 6.7+ MB

# %% [markdown]
# **DATA SET 'title_ratings' PRE PROCESSING**

# %%
title_ratings.info() # checks the info of the data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 73856 entries, tt10356526 to tt9894098
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   averagerating  73856 non-null  float64
#  1   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1)
# memory usage: 1.7+ MB

# %%
title_ratings.shape # checks the number of rows and columns in a dataset
# Out:
# (73856, 2)

# %%
title_ratings.head()
# Out:
#             averagerating  numvotes
# tconst
# tt10356526            8.3        31
# tt10384606            8.9       559
# tt1042974             6.4        20
# tt1043726             4.2     50352
# tt1060240             6.5        21

# %%
title_ratings.describe() #generates the statistical measures of central tendency
# Out:
#        averagerating      numvotes
# count   73856.000000  7.385600e+04
# mean        6.332729  3.523662e+03
# std         1.474978  3.029402e+04
# min         1.000000  5.000000e+00
# 25%         5.500000  1.400000e+01
# 50%         6.500000  4.900000e+01
# 75%         7.400000  2.820000e+02
# max        10.000000  1.841066e+06

# %%
title_ratings.isna().sum() #checks whether they are missig data
# Out:
# averagerating    0
# numvotes         0
# dtype: int64

# %% [markdown]
# The 'title_ratings' data set appears to have no missing data. which is good. so we look into the next data set

# %% [markdown]
# **DATA SET 'movie_budgets' PRE PROCESSING**

# %%
movie_budgets.info() # lets check the infor of the data set
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5782 entries, 1 to 82
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       5782 non-null   object
#  1   movie              5782 non-null   object
#  2   production_budget  5782 non-null   object
#  3   domestic_gross     5782 non-null   object
#  4   worldwide_gross    5782 non-null   object
# dtypes: object(5)
# memory usage: 271.0+ KB

# %%
movie_budgets.head()
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget domestic_gross worldwide_gross
# id
# 1       $425,000,000   $760,507,625  $2,776,345,279
# 2       $410,600,000   $241,063,875  $1,045,663,875
# 3       $350,000,000    $42,762,350    $149,762,350
# 4       $330,600,000   $459,005,868  $1,403,013,963
# 5       $317,000,000   $620,181,382  $1,316,721,747

# %%
movie_budgets.isna().sum() # checks and generates the sum of missing values
# Out:
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %% [markdown]
# The 'movie_budgets' data has no missing values, lets check for the placeholders values in the set.

# %%
movie_budgets.duplicated().sum()
# Out:
# 0

# %% [markdown]
# The movie budget data set has the $ sign in the values of the columns 'production_budget', 'domestic_gross'and 'worldwide_gross'. lets remove the sign using the replace() function

# %%
movie_budgets['production_budget'] = movie_budgets['production_budget'].str.replace('$', '')
movie_budgets['production_budget']
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4916\755616611.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   movie_budgets['production_budget'] = movie_budgets['production_budget'].str.replace('$', '')
# id
# 1     425,000,000
# 2     410,600,000
# 3     350,000,000
# 4     330,600,000
# 5     317,000,000
#          ...
# 78          7,000
# 79          6,000
# 80          5,000
# 81          1,400
# 82          1,100
# Name: production_budget, Length: 5782, dtype: object

# %%
movie_budgets['domestic_gross'] = movie_budgets['domestic_gross'].str.replace('$', '')
movie_budgets['domestic_gross']
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4916\251121778.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   movie_budgets['domestic_gross'] = movie_budgets['domestic_gross'].str.replace('$', '')
# id
# 1     760,507,625
# 2     241,063,875
# 3      42,762,350
# 4     459,005,868
# 5     620,181,382
#          ...
# 78              0
# 79         48,482
# 80          1,338
# 81              0
# 82        181,041
# Name: domestic_gross, Length: 5782, dtype: object

# %%
movie_budgets['worldwide_gross'] = movie_budgets['worldwide_gross'].str.replace('$', '')
movie_budgets['worldwide_gross']
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4916\1044086559.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   movie_budgets['worldwide_gross'] = movie_budgets['worldwide_gross'].str.replace('$', '')
# id
# 1     2,776,345,279
# 2     1,045,663,875
# 3       149,762,350
# 4     1,403,013,963
# 5     1,316,721,747
#           ...
# 78                0
# 79          240,495
# 80            1,338
# 81                0
# 82          181,041
# Name: worldwide_gross, Length: 5782, dtype: object

# %%
movie_budgets.head() # checks to confirm that the dollar sign has been successfully been removed.
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#    production_budget domestic_gross worldwide_gross
# id
# 1        425,000,000    760,507,625   2,776,345,279
# 2        410,600,000    241,063,875   1,045,663,875
# 3        350,000,000     42,762,350     149,762,350
# 4        330,600,000    459,005,868   1,403,013,963
# 5        317,000,000    620,181,382   1,316,721,747

# %% [markdown]
# **OBJECTIVE 1 : TO DETERMINE THE MOST PROFITABLE STUDIOS WHICH CAN BE USED FOR BENCHMARKING**

# %% [markdown]
# We will use the 'movie_gross'data set to determine the most profitable studios based on the domestic_gross

# %%
movie_gross.head()
# Out:
#                                             studio  domestic_gross  \
# title
# Toy Story 3                                     BV     415000000.0
# Alice in Wonderland (2010)                      BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# Inception                                       WB     292600000.0
# Shrek Forever After                           P/DW     238700000.0
#
#                                             foreign_gross  year
# title
# Toy Story 3                                     652000000  2010
# Alice in Wonderland (2010)                      691300000  2010
# Harry Potter and the Deathly Hallows Part 1     664300000  2010
# Inception                                       535700000  2010
# Shrek Forever After                             513900000  2010

# %% [markdown]
# First, lets generate the measure of central tendencies of the clumn 'domestic_gross'

# %%
movie_gross['domestic_gross'].mean() #checks the mean of the domestic_gross
# Out:
# 28745845.06698422

# %%
movie_gross['domestic_gross'].median() # checks median of the domestic_gross
# Out:
# 1400000.0

# %%
movie_gross['domestic_gross'].std() #generates the std dev of the domestic_gross column
# Out:
# 66982498.23736456

# %%
movie_gross['domestic_gross']. max() #checks the maximum value
# Out:
# 936700000.0

# %% [markdown]
# In the cells above, we will generate the studios whose domestic_gross is above the mean

# %%
domestic_gross_mean= movie_gross['domestic_gross'].mean()
domestic_gross_mean
# Out:
# 28745845.06698422

# %%
perfoming_studios_df = movie_gross.loc[movie_gross['domestic_gross'] >= movie_gross['domestic_gross'].mean()]
perfoming_studios_df
# Out:
#                                             studio  domestic_gross  \
# title
# Toy Story 3                                     BV     415000000.0
# Alice in Wonderland (2010)                      BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# Inception                                       WB     292600000.0
# Shrek Forever After                           P/DW     238700000.0
# ...                                            ...             ...
# Tyler Perry's Acrimony                         LGF      43500000.0
# Holmes and Watson                             Sony      30600000.0
# The Hate U Give                                Fox      29700000.0
# Death Wish (2018)                              MGM      34000000.0
# Nobody's Fool                                 Par.      31700000.0
#
#                                             foreign_gross  year
# title
# Toy Story 3                                     652000000  2010
# Alice in Wonderland (2010)                      691300000  2010
# Harry Potter and the Deathly Hallows Part 1     664300000  2010
# Inception                                       535700000  2010
# Shrek Forever After                             513900000  2010
# ...                                                   ...   ...
# Tyler Perry's Acrimony                            2900000  2018
# Holmes and Watson                                 9900000  2018
# The Hate U Give                                   5200000  2018
# Death Wish (2018)                                     NaN  2018
# Nobody's Fool                                     1800000  2018
#
# [837 rows x 4 columns]

# %%
#lets print the top 10 studios with highest domestic gross
ranked_perfoming_studios_df=perfoming_studios_df.sort_values(by=['domestic_gross'], ascending = False)
ranked_perfoming_studios_df.head(10)
# Out:
#                              studio  domestic_gross foreign_gross  year
# title
# Star Wars: The Force Awakens     BV     936700000.0      1,131.60  2015
# Black Panther                    BV     700100000.0     646900000  2018
# Avengers: Infinity War           BV     678800000.0      1,369.50  2018
# Jurassic World                 Uni.     652300000.0      1,019.40  2015
# Marvel's The Avengers            BV     623400000.0     895500000  2012
# Star Wars: The Last Jedi         BV     620200000.0     712400000  2017
# Incredibles 2                    BV     608600000.0     634200000  2018
# Rogue One: A Star Wars Story     BV     532200000.0     523900000  2016
# Beauty and the Beast (2017)      BV     504000000.0     759500000  2017
# Finding Dory                     BV     486300000.0     542300000  2016

# %%
perfoming_studios_data_df=ranked_perfoming_studios_df.head(50)
perfoming_studios_data_df
# Out:
#                                               studio  domestic_gross  \
# title
# Star Wars: The Force Awakens                      BV     936700000.0
# Black Panther                                     BV     700100000.0
# Avengers: Infinity War                            BV     678800000.0
# Jurassic World                                  Uni.     652300000.0
# Marvel's The Avengers                             BV     623400000.0
# Star Wars: The Last Jedi                          BV     620200000.0
# Incredibles 2                                     BV     608600000.0
# Rogue One: A Star Wars Story                      BV     532200000.0
# Beauty and the Beast (2017)                       BV     504000000.0
# Finding Dory                                      BV     486300000.0
# Avengers: Age of Ultron                           BV     459000000.0
# The Dark Knight Rises                             WB     448100000.0
# The Hunger Games: Catching Fire                  LGF     424700000.0
# Jurassic World: Fallen Kingdom                  Uni.     417700000.0
# Toy Story 3                                       BV     415000000.0
# Wonder Woman                                      WB     412600000.0
# Iron Man 3                                        BV     409000000.0
# Captain America: Civil War                        BV     408100000.0
# The Hunger Games                                 LGF     408000000.0
# Jumanji: Welcome to the Jungle                  Sony     404500000.0
# Frozen                                            BV     400700000.0
# Guardians of the Galaxy Vol. 2                    BV     389800000.0
# Harry Potter and the Deathly Hallows Part 2       WB     381000000.0
# The Secret Life of Pets                         Uni.     368400000.0
# Despicable Me 2                                 Uni.     368100000.0
# The Jungle Book (2016)                            BV     364000000.0
# Deadpool                                         Fox     363100000.0
# Inside Out                                        BV     356500000.0
# Furious 7                                       Uni.     353000000.0
# Transformers: Dark of the Moon                  P/DW     352400000.0
# American Sniper                                   WB     350100000.0
# Zootopia                                          BV     341300000.0
# The Hunger Games: Mockingjay - Part 1            LGF     337100000.0
# Minions                                         Uni.     336000000.0
# Aquaman                                           WB     335100000.0
# Alice in Wonderland (2010)                        BV     334200000.0
# Spider-Man: Homecoming                          Sony     334200000.0
# Guardians of the Galaxy                           BV     333200000.0
# Batman v Superman: Dawn of Justice                WB     330400000.0
# It                                           WB (NL)     327500000.0
# Suicide Squad                                     WB     325100000.0
# Deadpool 2                                       Fox     318500000.0
# Thor: Ragnarok                                    BV     315100000.0
# Iron Man 2                                      Par.     312400000.0
# Skyfall                                         Sony     304400000.0
# The Hobbit: An Unexpected Journey            WB (NL)     303000000.0
# The Twilight Saga: Eclipse                      Sum.     300500000.0
# Harry Potter and the Deathly Hallows Part 1       WB     296000000.0
# Inception                                         WB     292600000.0
# The Twilight Saga: Breaking Dawn Part 2         LG/S     292300000.0
#
#                                             foreign_gross  year
# title
# Star Wars: The Force Awakens                     1,131.60  2015
# Black Panther                                   646900000  2018
# Avengers: Infinity War                           1,369.50  2018
# Jurassic World                                   1,019.40  2015
# Marvel's The Avengers                           895500000  2012
# Star Wars: The Last Jedi                        712400000  2017
# Incredibles 2                                   634200000  2018
# Rogue One: A Star Wars Story                    523900000  2016
# Beauty and the Beast (2017)                     759500000  2017
# Finding Dory                                    542300000  2016
# Avengers: Age of Ultron                         946400000  2015
# The Dark Knight Rises                           636800000  2012
# The Hunger Games: Catching Fire                 440300000  2013
# Jurassic World: Fallen Kingdom                  891800000  2018
# Toy Story 3                                     652000000  2010
# Wonder Woman                                    409300000  2017
# Iron Man 3                                      805800000  2013
# Captain America: Civil War                      745200000  2016
# The Hunger Games                                286400000  2012
# Jumanji: Welcome to the Jungle                  557600000  2017
# Frozen                                          875700000  2013
# Guardians of the Galaxy Vol. 2                  473900000  2017
# Harry Potter and the Deathly Hallows Part 2     960500000  2011
# The Secret Life of Pets                         507100000  2016
# Despicable Me 2                                 602700000  2013
# The Jungle Book (2016)                          602500000  2016
# Deadpool                                        420000000  2016
# Inside Out                                      501100000  2015
# Furious 7                                        1,163.00  2015
# Transformers: Dark of the Moon                  771400000  2011
# American Sniper                                 197300000  2014
# Zootopia                                        682500000  2016
# The Hunger Games: Mockingjay - Part 1           418200000  2014
# Minions                                         823400000  2015
# Aquaman                                         812700000  2018
# Alice in Wonderland (2010)                      691300000  2010
# Spider-Man: Homecoming                          546000000  2017
# Guardians of the Galaxy                         440200000  2014
# Batman v Superman: Dawn of Justice              543300000  2016
# It                                              372900000  2017
# Suicide Squad                                   421700000  2016
# Deadpool 2                                      460500000  2018
# Thor: Ragnarok                                  538900000  2017
# Iron Man 2                                      311500000  2010
# Skyfall                                         804200000  2012
# The Hobbit: An Unexpected Journey               718100000  2012
# The Twilight Saga: Eclipse                      398000000  2010
# Harry Potter and the Deathly Hallows Part 1     664300000  2010
# Inception                                       535700000  2010
# The Twilight Saga: Breaking Dawn Part 2         537400000  2012

# %% [markdown]
# From the analysis above we can see that the studio BV studio produced most movies with the highest domestic gross. let us use the barplot to visualize the studio and the domestic gross using the 'performing_studios_data_df'

# %%
sns.barplot(data=perfoming_studios_data_df, x="studio", y="domestic_gross")
# Out:
# <AxesSubplot:xlabel='studio', ylabel='domestic_gross'>

# %% [markdown]
# From the above visualization, it is clear that the studios BV,Uni,WB,LGF,Fox studio,P/DWWB, NL, Par,Sum and LG/S has produced movies with the highest domestic_gross making them best suitable for benchmarking

# %% [markdown]
# From the dataset 'performing_studios_data_pd' we can also analyze the top 20 best movies with the highest domestic gross also using a barplot

# %%
best_movies_df=perfoming_studios_df.head(5)
best_movies_df
# Out:
#                                             studio  domestic_gross  \
# title
# Toy Story 3                                     BV     415000000.0
# Alice in Wonderland (2010)                      BV     334200000.0
# Harry Potter and the Deathly Hallows Part 1     WB     296000000.0
# Inception                                       WB     292600000.0
# Shrek Forever After                           P/DW     238700000.0
#
#                                             foreign_gross  year
# title
# Toy Story 3                                     652000000  2010
# Alice in Wonderland (2010)                      691300000  2010
# Harry Potter and the Deathly Hallows Part 1     664300000  2010
# Inception                                       535700000  2010
# Shrek Forever After                             513900000  2010

# %% [markdown]
# **OBJECTIVE 2: TO DETERMINE WHAT MOVIES ARE MORE PROFITABLE**

# %% [markdown]
# IN order to determine the movies that are  most profitable, we will need to use the `movie_budgets` to analyze the profitability.
# * we will use the data to analyze the movies with the highest domestic gross incomes
# * we will also use the data to analyze movies with high production costs

# %%
movie_budgets.head() # checks the outlook of the df
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#     production_budget  domestic_gross worldwide_gross
# id
# 1         425000000.0     760507625.0      2776345279
# 2         410600000.0     241063875.0      1045663875
# 3         350000000.0      42762350.0       149762350
# 4         330600000.0     459005868.0      1403013963
# 5         317000000.0     620181382.0      1316721747

# %%
movie_budgets.info() #checks the info

# %%
movie_budgets['production_budget'] = movie_budgets['production_budget'].str.replace('$', '')
movie_budgets['production_budget']
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4916\755616611.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   movie_budgets['production_budget'] = movie_budgets['production_budget'].str.replace('$', '')
# id
# 1     425,000,000
# 2     410,600,000
# 3     350,000,000
# 4     330,600,000
# 5     317,000,000
#          ...
# 78          7,000
# 79          6,000
# 80          5,000
# 81          1,400
# 82          1,100
# Name: production_budget, Length: 5782, dtype: object

# %%
movie_budgets['production_budget'] = movie_budgets['production_budget'].str.replace(',', '')
movie_budgets['production_budget']
# Out:
# id
# 1     425000000
# 2     410600000
# 3     350000000
# 4     330600000
# 5     317000000
#         ...
# 78         7000
# 79         6000
# 80         5000
# 81         1400
# 82         1100
# Name: production_budget, Length: 5782, dtype: object

# %%
movie_budgets['domestic_gross'] = movie_budgets['domestic_gross'].str.replace(',', '')
movie_budgets['domestic_gross']
# Out:
# id
# 1     760507625
# 2     241063875
# 3      42762350
# 4     459005868
# 5     620181382
#         ...
# 78            0
# 79        48482
# 80         1338
# 81            0
# 82       181041
# Name: domestic_gross, Length: 5782, dtype: object

# %%
movie_budgets['domestic_gross'] = movie_budgets['domestic_gross'].str.replace('$', '')
movie_budgets['domestic_gross']
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4916\251121778.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   movie_budgets['domestic_gross'] = movie_budgets['domestic_gross'].str.replace('$', '')
# id
# 1     760507625
# 2     241063875
# 3      42762350
# 4     459005868
# 5     620181382
#         ...
# 78            0
# 79        48482
# 80         1338
# 81            0
# 82       181041
# Name: domestic_gross, Length: 5782, dtype: object

# %%
movie_budgets['worldwide_gross'] = movie_budgets['worldwide_gross'].str.replace('$', '')
movie_budgets['worldwide_gross']
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4916\1044086559.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   movie_budgets['worldwide_gross'] = movie_budgets['worldwide_gross'].str.replace('$', '')
# id
# 1     2,776,345,279
# 2     1,045,663,875
# 3       149,762,350
# 4     1,403,013,963
# 5     1,316,721,747
#           ...
# 78                0
# 79          240,495
# 80            1,338
# 81                0
# 82          181,041
# Name: worldwide_gross, Length: 5782, dtype: object

# %%
movie_budgets['worldwide_gross'] = movie_budgets['worldwide_gross'].str.replace(',', '')
movie_budgets['worldwide_gross']
# Out:
# id
# 1     2776345279
# 2     1045663875
# 3      149762350
# 4     1403013963
# 5     1316721747
#          ...
# 78             0
# 79        240495
# 80          1338
# 81             0
# 82        181041
# Name: worldwide_gross, Length: 5782, dtype: object

# %%
movie_budgets.isna().sum()
# Out:
# release_date         0
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %%
movie_budgets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5782 entries, 1 to 82
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   release_date       5782 non-null   object
#  1   movie              5782 non-null   object
#  2   production_budget  5782 non-null   object
#  3   domestic_gross     5782 non-null   object
#  4   worldwide_gross    5782 non-null   object
# dtypes: object(5)
# memory usage: 271.0+ KB

# %%
movie_budgets['production_budget'] = movie_budgets['production_budget'].astype(float)
movie_budgets['production_budget']
# Out:
# id
# 1     425000000.0
# 2     410600000.0
# 3     350000000.0
# 4     330600000.0
# 5     317000000.0
#          ...
# 78         7000.0
# 79         6000.0
# 80         5000.0
# 81         1400.0
# 82         1100.0
# Name: production_budget, Length: 5782, dtype: float64

# %%
movie_budgets['domestic_gross'] = movie_budgets['domestic_gross'].astype(float)
movie_budgets['domestic_gross']
# Out:
# id
# 1     760507625.0
# 2     241063875.0
# 3      42762350.0
# 4     459005868.0
# 5     620181382.0
#          ...
# 78            0.0
# 79        48482.0
# 80         1338.0
# 81            0.0
# 82       181041.0
# Name: domestic_gross, Length: 5782, dtype: float64

# %%
>>> df = movie_budgets.fillna(0)
>>> df.worldwide_gross.astype(float)
# Out:
# id
# 1     2.776345e+09
# 2     1.045664e+09
# 3     1.497624e+08
# 4     1.403014e+09
# 5     1.316722e+09
#           ...
# 78    0.000000e+00
# 79    2.404950e+05
# 80    1.338000e+03
# 81    0.000000e+00
# 82    1.810410e+05
# Name: worldwide_gross, Length: 5782, dtype: float64

# %%
movie_budgets.describe() #generates the statistical measures
# Out:
#        production_budget  domestic_gross
# count       5.782000e+03    5.782000e+03
# mean        3.158776e+07    4.187333e+07
# std         4.181208e+07    6.824060e+07
# min         1.100000e+03    0.000000e+00
# 25%         5.000000e+06    1.429534e+06
# 50%         1.700000e+07    1.722594e+07
# 75%         4.000000e+07    5.234866e+07
# max         4.250000e+08    9.366622e+08

# %%
movie_budgets.head()
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#     production_budget  domestic_gross worldwide_gross
# id
# 1         425000000.0     760507625.0      2776345279
# 2         410600000.0     241063875.0      1045663875
# 3         350000000.0      42762350.0       149762350
# 4         330600000.0     459005868.0      1403013963
# 5         317000000.0     620181382.0      1316721747

# %%
#checking the besp perfoming movies based on the domestic gross
movie_perf_df= movie_budgets.loc[movie_budgets['domestic_gross']>=movie_budgets['domestic_gross'].mean()]
movie_perf_df
# Out:
#     release_date                                        movie  \
# id
# 1   Dec 18, 2009                                       Avatar
# 2   May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 3    Jun 7, 2019                                 Dark Phoenix
# 4    May 1, 2015                      Avengers: Age of Ultron
# 5   Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
# ..           ...                                          ...
# 7   Jul 14, 1999                      The Blair Witch Project
# 93  Sep 25, 2009                          Paranormal Activity
# 8   Jun 11, 2004                            Napoleon Dynamite
# 37  Oct 17, 1978                                    Halloween
# 46  Jun 30, 1972                                  Deep Throat
#
#     production_budget  domestic_gross worldwide_gross
# id
# 1         425000000.0     760507625.0      2776345279
# 2         410600000.0     241063875.0      1045663875
# 3         350000000.0      42762350.0       149762350
# 4         330600000.0     459005868.0      1403013963
# 5         317000000.0     620181382.0      1316721747
# ..                ...             ...             ...
# 7            600000.0     140539099.0       248300000
# 93           450000.0     107918810.0       194183034
# 8            400000.0      44540956.0        46122713
# 37           325000.0      47000000.0        70000000
# 46            25000.0      45000000.0        45000000
#
# [1760 rows x 5 columns]

# %% [markdown]
# from the analysis above, there are 1760 movies with domestic gross which is equal to or greter than the mean.let us visually illustrate the seaborn barplot

# %%
#lets print the top 10 studios with highest domestic gross
ranked_movie_perf_df=movie_perf_df.sort_values(by=['domestic_gross'], ascending = False)
ranked_movie_perf_df.head(50)
# Out:
#     release_date                                          movie  \
# id
# 6   Dec 18, 2015           Star Wars Ep. VII: The Force Awakens
# 1   Dec 18, 2009                                         Avatar
# 42  Feb 16, 2018                                  Black Panther
# 7   Apr 27, 2018                         Avengers: Infinity War
# 43  Dec 19, 1997                                        Titanic
# 34  Jun 12, 2015                                 Jurassic World
# 27   May 4, 2012                                   The Avengers
# 5   Dec 15, 2017              Star Wars Ep. VIII: The Last Jedi
# 44  Jun 15, 2018                                  Incredibles 2
# 75  Jul 18, 2008                                The Dark Knight
# 45  Dec 16, 2016                   Rogue One: A Star Wars Story
# 35  Mar 17, 2017                           Beauty and the Beast
# 46  Jun 17, 2016                                   Finding Dory
# 4   May 19, 1999            Star Wars Ep. I: The Phantom Menace
# 65  May 25, 1977                   Star Wars Ep. IV: A New Hope
# 4    May 1, 2015                        Avengers: Age of Ultron
# 11  Jul 20, 2012                          The Dark Knight Rises
# 93  May 19, 2004                                        Shrek 2
# 26  Jun 11, 1982                      ET: The Extra-Terrestrial
# 96   Mar 8, 2019                                 Captain Marvel
# 38  Nov 22, 2013                The Hunger Games: Catching Fire
# 28   Jul 7, 2006   Pirates of the Caribbean: Dead Manâs Chest
# 9   Jun 15, 1994                                  The Lion King
# 13  Jun 22, 2018                 Jurassic World: Fallen Kingdom
# 47  Jun 18, 2010                                    Toy Story 3
# 55   Jun 2, 2017                                   Wonder Woman
# 48   May 3, 2013                                     Iron Man 3
# 17   May 6, 2016                     Captain America: Civil War
# 38  Mar 23, 2012                               The Hunger Games
# 38  Dec 20, 2017                 Jumanji: Welcome to the Jungle
# 19   May 3, 2002                                     Spider-Man
# 36  Jun 24, 2009            Transformers: Revenge of the Fallen
# 56  Nov 22, 2013                                         Frozen
# 25  Jun 11, 1993                                  Jurassic Park
# 49   May 5, 2017                  Guardians of the Galaxy Vol 2
# 61  Jul 15, 2011  Harry Potter and the Deathly Hallows: Part II
# 25  May 30, 2003                                   Finding Nemo
# 5   May 19, 2005         Star Wars Ep. III: Revenge of the Sith
# 26  Dec 17, 2003  The Lord of the Rings: The Return of the King
# 86  Nov 13, 1991                           Beauty and the Beast
# 50  Jun 30, 2004                                   Spider-Man 2
# 60  Feb 25, 2004                      The Passion of the Christ
# 26   Jul 8, 2016                        The Secret Life of Pets
# 22   Jul 3, 2013                                Despicable Me 2
# 97  Apr 15, 2016                                The Jungle Book
# 56  Feb 12, 2016                                       Deadpool
# 98  Jun 19, 2015                                     Inside Out
# 67   Apr 3, 2015                                      Furious 7
# 64  Jun 29, 2011                 Transformers: Dark of the Moon
# 57  Dec 25, 2014                                American Sniper
#
#     production_budget  domestic_gross worldwide_gross
# id
# 6         306000000.0     936662225.0      2053311220
# 1         425000000.0     760507625.0      2776345279
# 42        200000000.0     700059566.0      1348258224
# 7         300000000.0     678815482.0      2048134200
# 43        200000000.0     659363944.0      2208208395
# 34        215000000.0     652270625.0      1648854864
# 27        225000000.0     623279547.0      1517935897
# 5         317000000.0     620181382.0      1316721747
# 44        200000000.0     608581744.0      1242520711
# 75        185000000.0     533720947.0      1001996207
# 45        200000000.0     532177324.0      1049102856
# 35        160000000.0     504014165.0      1259199706
# 46        200000000.0     486295561.0      1021215193
# 4         115000000.0     474544677.0      1027044677
# 65         11000000.0     460998007.0       786598007
# 4         330600000.0     459005868.0      1403013963
# 11        275000000.0     448139099.0      1084439099
# 93         70000000.0     441226247.0       937008132
# 26         10500000.0     435110554.0       792965326
# 96        175000000.0     426525952.0      1123061550
# 38        130000000.0     424668047.0       864868047
# 28        225000000.0     423315812.0      1066215812
# 9          79300000.0     421785283.0       986214868
# 13        170000000.0     417719760.0      1305772799
# 47        200000000.0     415004880.0      1068879522
# 55        150000000.0     412563408.0       821133378
# 48        200000000.0     408992272.0      1215392272
# 17        250000000.0     408084349.0      1140069413
# 38         80000000.0     408010692.0       677923379
# 38         90000000.0     404508916.0       964496193
# 19        139000000.0     403706375.0       821706375
# 36        210000000.0     402111870.0       836519699
# 56        150000000.0     400738009.0      1272469910
# 25         63000000.0     395708305.0      1038812584
# 49        200000000.0     389813101.0       862316233
# 61        125000000.0     381193157.0      1341693157
# 25         94000000.0     380529370.0       936429370
# 5         115000000.0     380270577.0       848998877
# 26         94000000.0     377845905.0      1141403341
# 86         20000000.0     376057266.0       608431132
# 50        200000000.0     373524485.0       795110670
# 60         25000000.0     370782930.0       622341924
# 26         75000000.0     368384330.0       886750534
# 22         76000000.0     368065385.0       975216835
# 97        175000000.0     364001123.0       962854547
# 56         58000000.0     363070709.0       801025593
# 98        175000000.0     356461711.0       854235992
# 67        190000000.0     353007020.0      1518722794
# 64        195000000.0     352390543.0      1123790543
# 57         58000000.0     350126372.0       547326372

# %% [markdown]
# From the above data, we can see the top 10 movies with the highest domestic gross.

# %%
plotting_data=ranked_movie_perf_df.head(10)
plotting_data
# Out:
#     release_date                                 movie  production_budget  \
# id
# 6   Dec 18, 2015  Star Wars Ep. VII: The Force Awakens        306000000.0
# 1   Dec 18, 2009                                Avatar        425000000.0
# 42  Feb 16, 2018                         Black Panther        200000000.0
# 7   Apr 27, 2018                Avengers: Infinity War        300000000.0
# 43  Dec 19, 1997                               Titanic        200000000.0
# 34  Jun 12, 2015                        Jurassic World        215000000.0
# 27   May 4, 2012                          The Avengers        225000000.0
# 5   Dec 15, 2017     Star Wars Ep. VIII: The Last Jedi        317000000.0
# 44  Jun 15, 2018                         Incredibles 2        200000000.0
# 75  Jul 18, 2008                       The Dark Knight        185000000.0
#
#     domestic_gross worldwide_gross
# id
# 6      936662225.0      2053311220
# 1      760507625.0      2776345279
# 42     700059566.0      1348258224
# 7      678815482.0      2048134200
# 43     659363944.0      2208208395
# 34     652270625.0      1648854864
# 27     623279547.0      1517935897
# 5      620181382.0      1316721747
# 44     608581744.0      1242520711
# 75     533720947.0      1001996207

# %%
sns.barplot(data=plotting_data, x="domestic_gross", y="movie")
#generates a barplot illustating most profitable movies based on the domestic gross
# Out:
# <AxesSubplot:xlabel='domestic_gross', ylabel='movie'>

# %% [markdown]
# Lets check on the most cost friendly movies to produce

# %%
movie_budgets['production_budget'].mean()
# Out:
# 31587757.0965064

# %%
#checking the besp perfoming movies based on the domestic gross
cost_df= movie_budgets.loc[movie_budgets['production_budget']<=movie_budgets['production_budget'].mean()]
cost_df
# Out:
#     release_date                          movie  production_budget  \
# id
# 20  Aug 15, 1979                 Apocalypse Now         31500000.0
# 21  Apr 15, 2016                       Criminal         31500000.0
# 22  Apr 12, 2013                             42         31000000.0
# 23   Nov 2, 2012                         Flight         31000000.0
# 24  Dec 29, 1995           Mr. Hollandâs Opus         31000000.0
# ..           ...                            ...                ...
# 78  Dec 31, 2018                         Red 11             7000.0
# 79   Apr 2, 1999                      Following             6000.0
# 80  Jul 13, 2005  Return to the Land of Wonders             5000.0
# 81  Sep 29, 2015           A Plague So Pleasant             1400.0
# 82   Aug 5, 2005              My Date With Drew             1100.0
#
#     domestic_gross worldwide_gross
# id
# 20      78800000.0        81250485
# 21      14708696.0        38771262
# 22      95020213.0        97470701
# 23      93772375.0       160558438
# 24      82582604.0       106282604
# ..             ...             ...
# 78             0.0               0
# 79         48482.0          240495
# 80          1338.0            1338
# 81             0.0               0
# 82        181041.0          181041
#
# [3963 rows x 5 columns]

# %% [markdown]
# From the Analysis above, there are 3963 observations whose production budgets are below the average budget for production.lets illustrate the distribution of the first 50 after ranking using a scaterplot

# %%
ranked_cost_df =cost_df.sort_values(by=['production_budget'], ascending = True)
ranked_cost_df.head(50)
# Out:
#     release_date                              movie  production_budget  \
# id
# 82   Aug 5, 2005                  My Date With Drew             1100.0
# 81  Sep 29, 2015               A Plague So Pleasant             1400.0
# 80  Jul 13, 2005      Return to the Land of Wonders             5000.0
# 79   Apr 2, 1999                          Following             6000.0
# 77  Dec 31, 2004                    The Mongol King             7000.0
# 74  Feb 26, 1993                        El Mariachi             7000.0
# 78  Dec 31, 2018                             Red 11             7000.0
# 76  May 26, 2006                             Cavite             7000.0
# 75   Oct 8, 2004                             Primer             7000.0
# 73  Jan 13, 2012                          Newlyweds             9000.0
# 66   Mar 9, 2001                            Dayereh            10000.0
# 67  Apr 28, 2006                              Clean            10000.0
# 68   Jul 6, 2001                               Cure            10000.0
# 72  May 19, 2015                   Family Motocross            10000.0
# 70   Apr 1, 1996                               Bang            10000.0
# 71  Aug 14, 2008    The Rise and Fall of Miss Thang            10000.0
# 69  May 28, 2004                     On the Downlow            10000.0
# 65  Dec 31, 2007                        Tin Can Man            12000.0
# 64  Apr 28, 2006           Grip: A Criminal's Story            12000.0
# 63  Apr 11, 1997                     Pink Flamingos            12000.0
# 62  Dec 31, 2014               Stories of Our Lives            15000.0
# 61   Apr 2, 2010                   Breaking Upwards            15000.0
# 60   Jun 2, 2006                    The Puffy Chair            15000.0
# 59  Nov 25, 2011                         The Ridges            17300.0
# 55  Dec 31, 2003                           Flywheel            20000.0
# 56   Jan 4, 2013           All Superheroes Must Die            20000.0
# 57  Apr 21, 2015                      The Front Man            20000.0
# 58   Dec 1, 2003                       Steel Spirit            20000.0
# 54  Dec 31, 2014                          Dry Spell            22000.0
# 53   Aug 1, 1991                            Slacker            23000.0
# 52   Dec 1, 2015                        Dutch Kills            25000.0
# 51  Apr 21, 2015                                Ten            25000.0
# 50  Jun 13, 2003                             Manito            25000.0
# 49   Sep 1, 2015                             Exeter            25000.0
# 48  Jan 14, 2000                      The Terrorist            25000.0
# 47   Aug 1, 1997              In the Company of Men            25000.0
# 46  Jun 30, 1972                        Deep Throat            25000.0
# 43  Oct 19, 1994                             Clerks            27000.0
# 44  Dec 24, 1999                     Pink Narcissus            27000.0
# 45  Jan 27, 2017                              Emily            27000.0
# 37  Jul 18, 2008            The Legend of God's Gun            30000.0
# 38  Mar 18, 2016                             Krisha            30000.0
# 42  Dec 31, 2013                         Paraphobia            30000.0
# 40  Apr 29, 2005                        Funny Ha Ha            30000.0
# 41  Oct 15, 2010                       Down Terrace            30000.0
# 39   Sep 1, 2006                Mutual Appreciation            30000.0
# 36  Dec 31, 2014                         Happy 40th            35000.0
# 35  Oct 25, 2013  Her Cry: La Llorona Investigation            35000.0
# 34   Jul 1, 1991                     The Last Waltz            35000.0
# 33  Mar 31, 2012                    Foreign Letters            40000.0
#
#     domestic_gross worldwide_gross
# id
# 82        181041.0          181041
# 81             0.0               0
# 80          1338.0            1338
# 79         48482.0          240495
# 77           900.0             900
# 74       2040920.0         2041928
# 78             0.0               0
# 76         70071.0           71644
# 75        424760.0          841926
# 73          4584.0            4584
# 66        673780.0          673780
# 67        138711.0          138711
# 68         94596.0           94596
# 72             0.0               0
# 70           527.0             527
# 71           401.0             401
# 69          1987.0            1987
# 65             0.0               0
# 64          1336.0            1336
# 63        413802.0          413802
# 62             0.0               0
# 61        115592.0          115592
# 60        194523.0          195254
# 59             0.0               0
# 55             0.0               0
# 56             0.0               0
# 57             0.0               0
# 58             0.0               0
# 54             0.0               0
# 53       1227508.0         1227508
# 52             0.0               0
# 51             0.0               0
# 50             0.0               0
# 49             0.0          489792
# 48        195043.0          195043
# 47       2883661.0         2883661
# 46      45000000.0        45000000
# 43       3073428.0         3894240
# 44          8231.0            8231
# 45          3547.0            3547
# 37        243768.0          243768
# 38        144822.0          144822
# 42             0.0               0
# 40         77070.0           82698
# 41          9812.0            9812
# 39        103509.0          103509
# 36             0.0               0
# 35             0.0               0
# 34        321952.0          322563
# 33             0.0               0

# %%
#lets illustrate the distribution using a sctter diagram for the first 20 observations
plotting_cost_df=ranked_cost_df.head(20)
plotting_cost_df
# Out:
#     release_date                            movie  production_budget  \
# id
# 82   Aug 5, 2005                My Date With Drew             1100.0
# 81  Sep 29, 2015             A Plague So Pleasant             1400.0
# 80  Jul 13, 2005    Return to the Land of Wonders             5000.0
# 79   Apr 2, 1999                        Following             6000.0
# 77  Dec 31, 2004                  The Mongol King             7000.0
# 74  Feb 26, 1993                      El Mariachi             7000.0
# 78  Dec 31, 2018                           Red 11             7000.0
# 76  May 26, 2006                           Cavite             7000.0
# 75   Oct 8, 2004                           Primer             7000.0
# 73  Jan 13, 2012                        Newlyweds             9000.0
# 66   Mar 9, 2001                          Dayereh            10000.0
# 67  Apr 28, 2006                            Clean            10000.0
# 68   Jul 6, 2001                             Cure            10000.0
# 72  May 19, 2015                 Family Motocross            10000.0
# 70   Apr 1, 1996                             Bang            10000.0
# 71  Aug 14, 2008  The Rise and Fall of Miss Thang            10000.0
# 69  May 28, 2004                   On the Downlow            10000.0
# 65  Dec 31, 2007                      Tin Can Man            12000.0
# 64  Apr 28, 2006         Grip: A Criminal's Story            12000.0
# 63  Apr 11, 1997                   Pink Flamingos            12000.0
#
#     domestic_gross worldwide_gross
# id
# 82        181041.0          181041
# 81             0.0               0
# 80          1338.0            1338
# 79         48482.0          240495
# 77           900.0             900
# 74       2040920.0         2041928
# 78             0.0               0
# 76         70071.0           71644
# 75        424760.0          841926
# 73          4584.0            4584
# 66        673780.0          673780
# 67        138711.0          138711
# 68         94596.0           94596
# 72             0.0               0
# 70           527.0             527
# 71           401.0             401
# 69          1987.0            1987
# 65             0.0               0
# 64          1336.0            1336
# 63        413802.0          413802

# %%
sns.scatterplot(data=plotting_cost_df, x="production_budget", y="movie") #generating a scatter plot
# Out:
# <AxesSubplot:xlabel='production_budget', ylabel='movie'>

# %% [markdown]
# this is the distribution of the cost analysis when ascending =True, lets analyze the same when ascending = false

# %%
ranked_cost_df1 =cost_df.sort_values(by=['production_budget'], ascending = False)
ranked_cost_df1.head(50)
# Out:
#     release_date                                movie  production_budget  \
# id
# 20  Aug 15, 1979                       Apocalypse Now         31500000.0
# 21  Apr 15, 2016                             Criminal         31500000.0
# 28  Jul 29, 2015                             Vacation         31000000.0
# 34  Aug 25, 2017                  Birth of the Dragon         31000000.0
# 32  Sep 28, 2001                   Hearts in Atlantis         31000000.0
# 31  Apr 28, 2000                            Frequency         31000000.0
# 30  Feb 13, 2019                  Isnât it Romantic         31000000.0
# 29  Jul 18, 1990                        Arachnophobia         31000000.0
# 33  Jan 22, 2010               Extraordinary Measures         31000000.0
# 27   Mar 7, 2014             The Grand Budapest Hotel         31000000.0
# 25  Dec 18, 1985                        Out of Africa         31000000.0
# 24  Dec 29, 1995                 Mr. Hollandâs Opus         31000000.0
# 23   Nov 2, 2012                               Flight         31000000.0
# 22  Apr 12, 2013                                   42         31000000.0
# 26  Jun 29, 1979                            Moonraker         31000000.0
# 35  Oct 20, 1995                           Get Shorty         30250000.0
# 53   Oct 4, 2013                        Runner Runner         30000000.0
# 56   Mar 3, 2006                          Ultraviolet         30000000.0
# 55  Apr 28, 2017          Baahubali 2: The Conclusion         30000000.0
# 54   Feb 6, 1998              The Replacement Killers         30000000.0
# 49  Nov 19, 2010                  The Next Three Days         30000000.0
# 52  Jan 19, 2005               Assault On Precinct 13         30000000.0
# 51   Aug 6, 2004                    Little Black Book         30000000.0
# 50  Jan 12, 2018                           Proud Mary         30000000.0
# 58  Aug 19, 2011                         Fright Night         30000000.0
# 57  Oct 21, 2005                        North Country         30000000.0
# 66   Aug 1, 1986                      Howard the Duck         30000000.0
# 59  Sep 15, 2017                              mother!         30000000.0
# 60   Oct 9, 2015                           Steve Jobs         30000000.0
# 61  Jul 17, 2002                  Eight Legged Freaks         30000000.0
# 62  Jul 19, 1996                                 Fled         30000000.0
# 63   Jun 4, 2010                               Splice         30000000.0
# 64  Apr 18, 2008                           88 Minutes         30000000.0
# 65   Apr 9, 2004                  The Whole Ten Yards         30000000.0
# 47  Aug 25, 2017                            Ballerina         30000000.0
# 67  Oct 24, 2008                      Pride and Glory         30000000.0
# 48  Sep 17, 2004                             Mr. 3000         30000000.0
# 39  Jul 15, 2011                      Winnie the Pooh         30000000.0
# 46  Jul 21, 2006               My Super Ex-Girlfriend         30000000.0
# 35   Aug 1, 2014                            Get on Up         30000000.0
# 27   Apr 7, 2006                        Take the Lead         30000000.0
# 28   Mar 2, 2018                           Death Wish         30000000.0
# 29  Nov 24, 2010                 Love and Other Drugs         30000000.0
# 30   Jun 3, 2015                            Entourage         30000000.0
# 31   Jun 1, 2001  What's the Worst That Could Happen?         30000000.0
# 32   Feb 8, 2013                         Side Effects         30000000.0
# 33   Sep 9, 2009                                    9         30000000.0
# 34   Jul 2, 2014                 Deliver Us from Evil         30000000.0
# 36  Dec 25, 2017                       Mollyâs Game         30000000.0
# 45   Feb 4, 2011                              Sanctum         30000000.0
#
#     domestic_gross worldwide_gross
# id
# 20      78800000.0        81250485
# 21      14708696.0        38771262
# 28      58884188.0       102306500
# 34       6901965.0         7220490
# 32      24185781.0        30885781
# 31      44983704.0        68079671
# 30      48791187.0        48791187
# 29      53208180.0        53208180
# 33      12482741.0        15826984
# 27      59076019.0       163981261
# 25      79096868.0       258210860
# 24      82582604.0       106282604
# 23      93772375.0       160558438
# 22      95020213.0        97470701
# 26      70300000.0       210300000
# 35      72021008.0       115021008
# 53      19316646.0        60512680
# 56      18522064.0        30962112
# 55      18985794.0       263502914
# 54      19035741.0        19035741
# 49      21148651.0        67255916
# 52      20040895.0        36040895
# 51      20422207.0        21758371
# 50      20868638.0        21709539
# 58      18298649.0        40520649
# 57      18324242.0        23676771
# 66      16295774.0        16295774
# 59      17800004.0        42531076
# 60      17766658.0        35579007
# 61      17266505.0        36722311
# 62      17192205.0        19892205
# 63      17010170.0        28542494
# 64      16930884.0        32955399
# 65      16323969.0        26323969
# 47      21858070.0        96892829
# 67      15740721.0        43440721
# 48      21800302.0        21827296
# 39      26692846.0        50145607
# 46      22530295.0        60772856
# 35      30569935.0        33339868
# 27      34742066.0        65390493
# 28      34017028.0        48575965
# 29      32367005.0       102716321
# 30      32363404.0        46438538
# 31      32267774.0        38462071
# 32      32172757.0        66742138
# 33      31749894.0        48559999
# 34      30577122.0        87956618
# 36      28780744.0        53296424
# 45      23209310.0       108957098

# %%
#lets illustrate the distribution using a sctter diagram for the first 20 observations
plotting_cost_df1=ranked_cost_df1.head(20)
plotting_cost_df1
# Out:
#     release_date                        movie  production_budget  \
# id
# 20  Aug 15, 1979               Apocalypse Now         31500000.0
# 21  Apr 15, 2016                     Criminal         31500000.0
# 28  Jul 29, 2015                     Vacation         31000000.0
# 34  Aug 25, 2017          Birth of the Dragon         31000000.0
# 32  Sep 28, 2001           Hearts in Atlantis         31000000.0
# 31  Apr 28, 2000                    Frequency         31000000.0
# 30  Feb 13, 2019          Isnât it Romantic         31000000.0
# 29  Jul 18, 1990                Arachnophobia         31000000.0
# 33  Jan 22, 2010       Extraordinary Measures         31000000.0
# 27   Mar 7, 2014     The Grand Budapest Hotel         31000000.0
# 25  Dec 18, 1985                Out of Africa         31000000.0
# 24  Dec 29, 1995         Mr. Hollandâs Opus         31000000.0
# 23   Nov 2, 2012                       Flight         31000000.0
# 22  Apr 12, 2013                           42         31000000.0
# 26  Jun 29, 1979                    Moonraker         31000000.0
# 35  Oct 20, 1995                   Get Shorty         30250000.0
# 53   Oct 4, 2013                Runner Runner         30000000.0
# 56   Mar 3, 2006                  Ultraviolet         30000000.0
# 55  Apr 28, 2017  Baahubali 2: The Conclusion         30000000.0
# 54   Feb 6, 1998      The Replacement Killers         30000000.0
#
#     domestic_gross worldwide_gross
# id
# 20      78800000.0        81250485
# 21      14708696.0        38771262
# 28      58884188.0       102306500
# 34       6901965.0         7220490
# 32      24185781.0        30885781
# 31      44983704.0        68079671
# 30      48791187.0        48791187
# 29      53208180.0        53208180
# 33      12482741.0        15826984
# 27      59076019.0       163981261
# 25      79096868.0       258210860
# 24      82582604.0       106282604
# 23      93772375.0       160558438
# 22      95020213.0        97470701
# 26      70300000.0       210300000
# 35      72021008.0       115021008
# 53      19316646.0        60512680
# 56      18522064.0        30962112
# 55      18985794.0       263502914
# 54      19035741.0        19035741

# %%
#lets illustrate the distribution using a sctter diagram for the first 20 observations
plotting_cost_df1=ranked_cost_df1.head(20)
plotting_cost_df1
# Out:
#     release_date                        movie  production_budget  \
# id
# 20  Aug 15, 1979               Apocalypse Now         31500000.0
# 21  Apr 15, 2016                     Criminal         31500000.0
# 28  Jul 29, 2015                     Vacation         31000000.0
# 34  Aug 25, 2017          Birth of the Dragon         31000000.0
# 32  Sep 28, 2001           Hearts in Atlantis         31000000.0
# 31  Apr 28, 2000                    Frequency         31000000.0
# 30  Feb 13, 2019          Isnât it Romantic         31000000.0
# 29  Jul 18, 1990                Arachnophobia         31000000.0
# 33  Jan 22, 2010       Extraordinary Measures         31000000.0
# 27   Mar 7, 2014     The Grand Budapest Hotel         31000000.0
# 25  Dec 18, 1985                Out of Africa         31000000.0
# 24  Dec 29, 1995         Mr. Hollandâs Opus         31000000.0
# 23   Nov 2, 2012                       Flight         31000000.0
# 22  Apr 12, 2013                           42         31000000.0
# 26  Jun 29, 1979                    Moonraker         31000000.0
# 35  Oct 20, 1995                   Get Shorty         30250000.0
# 53   Oct 4, 2013                Runner Runner         30000000.0
# 56   Mar 3, 2006                  Ultraviolet         30000000.0
# 55  Apr 28, 2017  Baahubali 2: The Conclusion         30000000.0
# 54   Feb 6, 1998      The Replacement Killers         30000000.0
#
#     domestic_gross worldwide_gross
# id
# 20      78800000.0        81250485
# 21      14708696.0        38771262
# 28      58884188.0       102306500
# 34       6901965.0         7220490
# 32      24185781.0        30885781
# 31      44983704.0        68079671
# 30      48791187.0        48791187
# 29      53208180.0        53208180
# 33      12482741.0        15826984
# 27      59076019.0       163981261
# 25      79096868.0       258210860
# 24      82582604.0       106282604
# 23      93772375.0       160558438
# 22      95020213.0        97470701
# 26      70300000.0       210300000
# 35      72021008.0       115021008
# 53      19316646.0        60512680
# 56      18522064.0        30962112
# 55      18985794.0       263502914
# 54      19035741.0        19035741

# %%
sns.scatterplot(data=plotting_cost_df1, x="production_budget", y="movie") #generating a scatter plot
# Out:
# <AxesSubplot:xlabel='production_budget', ylabel='movie'>
# C:\Users\ADMIN\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 128 (\x80) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\ADMIN\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 153 (\x99) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# From the above analysis, it is clear that most movies are distributed near the data mean value with very few movies being produced ith amount way lesser than the mean

# %%
data_df= movie_budgets.loc[movie_budgets['domestic_gross']> movie_budgets['production_budget']]
data_df
# Out:
#     release_date                                 movie  production_budget  \
# id
# 1   Dec 18, 2009                                Avatar        425000000.0
# 4    May 1, 2015               Avengers: Age of Ultron        330600000.0
# 5   Dec 15, 2017     Star Wars Ep. VIII: The Last Jedi        317000000.0
# 6   Dec 18, 2015  Star Wars Ep. VII: The Force Awakens        306000000.0
# 7   Apr 27, 2018                Avengers: Infinity War        300000000.0
# ..           ...                                   ...                ...
# 74  Feb 26, 1993                           El Mariachi             7000.0
# 75   Oct 8, 2004                                Primer             7000.0
# 76  May 26, 2006                                Cavite             7000.0
# 79   Apr 2, 1999                             Following             6000.0
# 82   Aug 5, 2005                     My Date With Drew             1100.0
#
#     domestic_gross worldwide_gross
# id
# 1      760507625.0      2776345279
# 4      459005868.0      1403013963
# 5      620181382.0      1316721747
# 6      936662225.0      2053311220
# 7      678815482.0      2048134200
# ..             ...             ...
# 74       2040920.0         2041928
# 75        424760.0          841926
# 76         70071.0           71644
# 79         48482.0          240495
# 82        181041.0          181041
#
# [2677 rows x 5 columns]

# %% [markdown]
# From this analysis of this objective we can make the following observations
# * The top ten movies with high domestic gross represent most profitable movies. the microsoft company can choose to produce movies similar to thse ones in order to attain more profits from the same
# * There are 2677 movies whose production costs are less than the domestic gross which translates into profits. microsoft can chose to produce movies which require lesser production cost than the top perfoming movies and still make profits. this option will optimize on resources and enable production of mutiple movies using resonable production_budgets

# %% [markdown]
# **OBJECTIVE 3: TO DETERMINE THE MOST PRODUCED MOVIE GENRES**

# %% [markdown]
# In this objective, we will use the `title_basics`data to analyze the genre which is mostly produced.this analysis is relevant to the project task in that;
# * we will be able to cross check whether the most profitable movies identidied in the previous analysis falls into the category of most produced genres
# * we will be able to cross chek whether the cost effective movies identified, falls in the category of most produced movies

# %% [markdown]
# title_basics.head()

# %%
by_genres= title_basics.sort_values(by='genres', ascending=False)
by_genres.head(50)
# Out:
#                                                 primary_title  \
# tconst
# tt10244910                                         C- Bar, II
# tt4892706                                         The Trouble
# tt5090548                        The Devil Came Up From Texas
# tt2175016                       The Redemption of Henry Myers
# tt6469146                                              Krasny
# tt4893452                          Winnetou & Old Shatterhand
# tt7790254                     Jesse James vs. The Black Train
# tt3125566                                            Boomtown
# tt4985906                                  Any Bullet Will Do
# tt8354434                                           Red Rider
# tt2179114                   The Life and Times of Jacob Flynn
# tt7493824                                American Gunslingers
# tt5901672                     Wild Bill Hickok: Swift Justice
# tt1478856                        The Righteous and the Wicked
# tt5574096                                       Hunter's Moon
# tt7280416                                              CHANCE
# tt5941336                              Sudsy Slim Rides Again
# tt2182390                               The Murder of Hi Good
# tt7802198                            Sex Terrorists on Wheels
# tt4121152                                          The Divide
# tt6010330                                             Destiny
# tt5338504           Cold Chains, Hard Hearts and Bloody Hands
# tt4475176                                      Prey for Death
# tt6266992                                       Blood Country
# tt1847552   Birth of a Legend: Billy the Kid & The Lincoln...
# tt3708370                                      Oro del Diablo
# tt2170435                                         Highclimber
# tt1666711                              Les colts de l'or noir
# tt4425614                                           The Gorda
# tt1555110                                         The Gundown
# tt7626082                                             Zerzura
# tt10449052                                      No Man's Land
# tt1578709                                           Snowblind
# tt10447604                                Fear Blood and Gold
# tt10137286                                 Witness Last Grave
# tt3598596                              Too Close to the Raven
# tt7339930                      The Last Days of Billy the Kid
# tt7468604                                   A Fistful of Lead
# tt2388976            The Shooting: Story of the Kane Brothers
# tt6233592                                          One by One
# tt8347414                                          Black Gold
# tt5862542                                Return to Zion Ranch
# tt5679402                    Stagecoach: The Texas Jack Story
# tt9135272                                       Eminence Hill
# tt1815808                                           Los Siete
# tt3195758                                  Burning Man: Bable
# tt6167392                                         Nubes Rojas
# tt3485850                                     Blood and Spurs
# tt6457286                                      The Broken Man
# tt5143890                                             Justice
#
#                                                original_title  start_year  \
# tconst
# tt10244910                                         C- Bar, II        2019
# tt4892706                                         The Trouble        2018
# tt5090548                        The Devil Came Up From Texas        2016
# tt2175016                       The Redemption of Henry Myers        2014
# tt6469146                                              Krasny        2016
# tt4893452                          Winnetou & Old Shatterhand        2016
# tt7790254                     Jesse James vs. The Black Train        2018
# tt3125566                                            Boomtown        2013
# tt4985906                                  Any Bullet Will Do        2018
# tt8354434                                           Red Rider        2014
# tt2179114                   The Life and Times of Jacob Flynn        2012
# tt7493824                                 The Last Gunslinger        2017
# tt5901672                     Wild Bill Hickok: Swift Justice        2016
# tt1478856                        The Righteous and the Wicked        2010
# tt5574096                                       Hunter's Moon        2016
# tt7280416                                              CHANCE        2017
# tt5941336                              Sudsy Slim Rides Again        2018
# tt2182390                               The Murder of Hi Good        2012
# tt7802198                            Sex Terrorists on Wheels        2018
# tt4121152                                          The Divide        2018
# tt6010330                                             Destiny        2018
# tt5338504           Cold Chains, Hard Hearts and Bloody Hands        2016
# tt4475176                                      Prey for Death        2015
# tt6266992                                       Blood Country        2017
# tt1847552   Birth of a Legend: Billy the Kid & The Lincoln...        2011
# tt3708370                                      Oro del Diablo        2013
# tt2170435                                         Highclimber        2011
# tt1666711                              Les colts de l'or noir        2010
# tt4425614                                           The Gorda        2015
# tt1555110                                         The Gundown        2011
# tt7626082                                             Zerzura        2017
# tt10449052                                      No Man's Land        2020
# tt1578709                                           Snowblind        2010
# tt10447604                                Fear Blood and Gold        2020
# tt10137286                                 Witness Last Grave        2019
# tt3598596                              Too Close to the Raven        2014
# tt7339930                      The Last Days of Billy the Kid        2017
# tt7468604                                   A Fistful of Lead        2018
# tt2388976            The Shooting: Story of the Kane Brothers        2013
# tt6233592                                          One by One        2016
# tt8347414                                          Black Gold        2018
# tt5862542                                Return to Zion Ranch        2017
# tt5679402                    Stagecoach: The Texas Jack Story        2016
# tt9135272                                       Eminence Hill        2019
# tt1815808                                           Los Siete        2010
# tt3195758                                  Burning Man: Bable        2014
# tt6167392                                         Nubes Rojas        2016
# tt3485850                                     Blood and Spurs        2014
# tt6457286                                      The Broken Man        2019
# tt5143890                                             Justice        2017
#
#             runtime_minutes   genres
# tconst
# tt10244910             64.0  Western
# tt4892706               NaN  Western
# tt5090548              46.0  Western
# tt2175016             101.0  Western
# tt6469146              86.0  Western
# tt4893452             117.0  Western
# tt7790254              80.0  Western
# tt3125566               NaN  Western
# tt4985906             110.0  Western
# tt8354434               NaN  Western
# tt2179114               NaN  Western
# tt7493824              80.0  Western
# tt5901672              77.0  Western
# tt1478856              96.0  Western
# tt5574096              90.0  Western
# tt7280416             120.0  Western
# tt5941336               NaN  Western
# tt2182390              65.0  Western
# tt7802198               NaN  Western
# tt4121152               NaN  Western
# tt6010330               NaN  Western
# tt5338504              92.0  Western
# tt4475176              80.0  Western
# tt6266992              89.0  Western
# tt1847552               NaN  Western
# tt3708370              91.0  Western
# tt2170435             110.0  Western
# tt1666711             105.0  Western
# tt4425614              60.0  Western
# tt1555110              97.0  Western
# tt7626082              87.0  Western
# tt10449052              NaN  Western
# tt1578709              95.0  Western
# tt10447604             91.0  Western
# tt10137286            132.0  Western
# tt3598596              62.0  Western
# tt7339930              80.0  Western
# tt7468604              86.0  Western
# tt2388976               NaN  Western
# tt6233592              71.0  Western
# tt8347414              49.0  Western
# tt5862542               NaN  Western
# tt5679402              90.0  Western
# tt9135272               NaN  Western
# tt1815808              87.0  Western
# tt3195758               NaN  Western
# tt6167392              64.0  Western
# tt3485850              90.0  Western
# tt6457286               NaN  Western
# tt5143890              92.0  Western

# %% [markdown]
# From our dataset`title_basics` we willanalyze the genres of movies that are mostly produced. we will then try to visualize the top ten most produced genres.

# %% [markdown]
# In the cell below, lets group the data by genre then sort it out using the 'primary_title' in order to derive the genres most produced

# %%
my_genre = title_basics.groupby('genres', as_index=False)['primary_title'].count().sort_values(by='primary_title', ascending=False)
my_genre.head(50)
# Out:
#                              genres  primary_title
# 694                     Documentary          32185
# 794                           Drama          21486
# 494                          Comedy           9177
# 992                          Horror           4372
# 527                    Comedy,Drama           3519
# 1078                       Thriller           3046
# 0                            Action           2219
# 433           Biography,Documentary           2115
# 872                   Drama,Romance           2079
# 537            Comedy,Drama,Romance           1558
# 695               Documentary,Drama           1554
# 608                  Comedy,Romance           1507
# 1061                        Romance           1454
# 751               Documentary,Music           1365
# 887                  Drama,Thriller           1335
# 730             Documentary,History           1289
# 1013                Horror,Thriller           1253
# 437   Biography,Documentary,History           1230
# 434     Biography,Documentary,Drama           1028
# 893                          Family            939
# 310                       Animation            828
# 795                    Drama,Family            784
# 65               Action,Crime,Drama            727
# 576                   Comedy,Horror            724
# 641                     Crime,Drama            723
# 627                           Crime            720
# 1069                         Sci-Fi            712
# 1018                          Music            701
# 786               Documentary,Sport            669
# 653            Crime,Drama,Thriller            665
# 773                Documentary,News            640
# 92                     Action,Drama            537
# 439     Biography,Documentary,Music            530
# 1044                        Mystery            516
# 413                       Biography            510
# 435    Biography,Documentary,Family            500
# 711              Documentary,Family            488
# 1003        Horror,Mystery,Thriller            479
# 172                       Adventure            477
# 928                         Fantasy            472
# 46                    Action,Comedy            457
# 843           Drama,Horror,Thriller            453
# 224           Adventure,Documentary            443
# 865          Drama,Mystery,Thriller            438
# 161                 Action,Thriller            434
# 968                         History            414
# 528             Comedy,Drama,Family            411
# 696        Documentary,Drama,Family            399
# 1033                        Musical            390
# 698       Documentary,Drama,History            374

# %%
genre_plot=my_genre.head(20) #generates the top 20 genres mostly procuced and which we will use for our visualization.
genre_plot
# Out:
#                              genres  primary_title
# 694                     Documentary          32185
# 794                           Drama          21486
# 494                          Comedy           9177
# 992                          Horror           4372
# 527                    Comedy,Drama           3519
# 1078                       Thriller           3046
# 0                            Action           2219
# 433           Biography,Documentary           2115
# 872                   Drama,Romance           2079
# 537            Comedy,Drama,Romance           1558
# 695               Documentary,Drama           1554
# 608                  Comedy,Romance           1507
# 1061                        Romance           1454
# 751               Documentary,Music           1365
# 887                  Drama,Thriller           1335
# 730             Documentary,History           1289
# 1013                Horror,Thriller           1253
# 437   Biography,Documentary,History           1230
# 434     Biography,Documentary,Drama           1028
# 893                          Family            939

# %%
sns.barplot(data=genre_plot, x="primary_title", y="genres")
#generates a barplot illustating most produced movie genres based on the title_basics dataset
# Out:
# <AxesSubplot:xlabel='primary_title', ylabel='genres'>

# %% [markdown]
# **CONCLUSION**

# %% [markdown]
# From this analysis we can make the following conclusions
#
# * Studios BV,Uni,WB,LGF,Fox studio,P/DWWB, NL, Par,Sum and LG/S has produced movies with the highest domestic_gross making them best suitable for benchmarking
# * The top ten movies with high domestic gross represent most profitable movies. the microsoft company can choose to produce movies similar to thse ones in order to attain more profits from the same
# * There are 2677 movies whose production costs are less than the domestic gross which translates into profits. microsoft can chose to produce movies which require lesser production cost than the top perfoming movies and still make profits. this option will optimize on resources and enable production of mutiple movies using resonable production_budgets
# * From the analysis of the genres mostly produced, microsoft should therefore consider producing  movie of the top ten genres mostly produced
